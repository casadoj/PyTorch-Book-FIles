# %% [markdown]
# # Chapter 15 - Transformers

# %% [markdown]
# ## `pipeline`

# %%
from transformers import pipeline

# %%
# Basic sentiment analysis
classifier = pipeline("sentiment-analysis")
result = classifier("I love working with transformers!")
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cuda:0
# [{'label': 'POSITIVE', 'score': 0.999541163444519}]

# %%
generator = pipeline("text-generation")
text = generator("The future of AI is")
print(text)
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'The future of AI is an important question for future generations, but it is always a question of when, not if."\n\n"We can\'t predict the future, but we can predict the potential," he added. "It\'s not like we have an infinite number of possibilities. And it\'s not like we have this infinite number of things to happen, but we have that possibility. The future is so huge that we need to think about what we are going to do next. Is it going to be a simulation, or is it going to be something we can do with our hands?"\n\nIn a statement released by the AI-defined conference, the company said: "We are proud to announce the release of the first ever virtual reality simulation. In the future, artificial intelligence will be able to solve many of the world\'s problems. This new simulation will be a real time measurement of how well a human brain performs on a task. We believe that this will be a huge milestone in the development of our next generation of computing in the real world."\n\nIn addition, the company said: "We are currently developing new virtual reality technologies to help our customers to navigate virtual reality applications on the go. We are also working on the development of new hardware for our VR headsets to allow us'}]

# %%
# Text generation with specific parameters
generator = pipeline(
    "text-generation",
    model="gpt2",
    max_length=50,
    temperature=0.7,
    top_k=50
)
text = generator("The future of AI is")
print(text)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "The future of AI is not yet clear. Most researchers have been trying to develop AI that works in a way that is safe and scalable, but many researchers don't seem to have the same amount of confidence in the science of AI. For example,"}]

# %% [markdown]
# ## `AutoTokenizer`

# %%
from transformers import AutoTokenizer

# %% [markdown]
# ### Sub-word tokenizer (BERT)

# %%
# Load BERT tokenizer which uses WordPiece
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# Let's use a sentence with some interesting words to tokenize
text = "The ultramarathoner prequalified for the immunohistochemistry conference in neuroscience."

# Tokenize the text
tokens = tokenizer.tokenize(text)
print("Tokens:", tokens)

# Get the token IDs
token_ids = tokenizer.encode(text)
print("\nToken IDs:", token_ids)

# Decode back to show special tokens
decoded = tokenizer.decode(token_ids)
print("\nDecoded with special tokens:", decoded)

# Let's see the mapping between tokens and their IDs
print("\nToken to ID mapping:")
for token in tokens:
    # Convert single token to ID
    id = tokenizer.convert_tokens_to_ids(token)
    print(f"{token:20} -> {id}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Tokens: ['the', 'ultra', '##mara', '##th', '##one', '##r', 'pre', '##qual', '##ified', 'for', 'the', 'im', '##mun', '##oh', '##isto', '##chemist', '##ry', 'conference', 'in', 'neuroscience', '.']
#
# Token IDs: [101, 1996, 11087, 28225, 2705, 5643, 2099, 3653, 26426, 7810, 2005, 1996, 10047, 23041, 11631, 20483, 24229, 2854, 3034, 1999, 23700, 1012, 102]
#
# Decoded with special tokens: [CLS] the ultramarathoner prequalified for the immunohistochemistry conference in neuroscience. [SEP]
#
# Token to ID mapping:
# the                  -> 1996
# ultra                -> 11087
# ##mara               -> 28225
# ##th                 -> 2705
# ##one                -> 5643
# ##r                  -> 2099
# pre                  -> 3653
# ##qual               -> 26426
# ##ified              -> 7810
# for                  -> 2005
# the                  -> 1996
# im                   -> 10047
# ##mun                -> 23041
# ##oh                 -> 11631
# ##isto               -> 20483
# ##chemist            -> 24229
# ##ry                 -> 2854
# conference           -> 3034
# in                   -> 1999
# neuroscience         -> 23700
# .                    -> 1012

# %%
text2 = "The preprocessing workflow using tokenizers and tokenizers123 also has preprocessingABC and post-processing!"

tokens2 = tokenizer.tokenize(text2)
print("Tokens:", tokens2)
# Out:
# Tokens: ['the', 'prep', '##ro', '##ces', '##sing', 'work', '##flow', 'using', 'token', '##izer', '##s', 'and', 'token', '##izer', '##s', '##12', '##3', 'also', 'has', 'prep', '##ro', '##ces', '##sing', '##ab', '##c', 'and', 'post', '-', 'processing', '!']

# %% [markdown]
# ### Byte-pair encoding (GPT)

# %%
# Load GPT-2 tokenizer which uses BPE
tokenizer = AutoTokenizer.from_pretrained('gpt2')

# Same sentence as before
text = "The ultramarathoner prequalified for the immunohistochemistry conference in neuroscience."

# Tokenize the text
tokens = tokenizer.tokenize(text)
print("Tokens:", tokens)

# Get the token IDs
token_ids = tokenizer.encode(text)
print("\nToken IDs:", token_ids)

# Decode back to show special tokens
decoded = tokenizer.decode(token_ids)
print("\nDecoded with special tokens:", decoded)

# Show the mapping between tokens and their IDs
print("\nToken to ID mapping:")
for token in tokens:
    id = tokenizer.convert_tokens_to_ids(token)
    print(f"{repr(token):20} -> {id}")  # Using repr() to show the special characters
# Out:
# Tokens: ['The', 'Ġult', 'ram', 'ar', 'athon', 'er', 'Ġpre', 'qualified', 'Ġfor', 'Ġthe', 'Ġimmun', 'oh', 'ist', 'ochemistry', 'Ġconference', 'Ġin', 'Ġneuroscience', '.']
#
# Token IDs: [464, 3789, 859, 283, 12938, 263, 662, 22557, 329, 262, 16217, 1219, 396, 37074, 4495, 287, 39738, 13]
#
# Decoded with special tokens: The ultramarathoner prequalified for the immunohistochemistry conference in neuroscience.
#
# Token to ID mapping:
# 'The'                -> 464
# 'Ġult'               -> 3789
# 'ram'                -> 859
# 'ar'                 -> 283
# 'athon'              -> 12938
# 'er'                 -> 263
# 'Ġpre'               -> 662
# 'qualified'          -> 22557
# 'Ġfor'               -> 329
# 'Ġthe'               -> 262
# 'Ġimmun'             -> 16217
# 'oh'                 -> 1219
# 'ist'                -> 396
# 'ochemistry'         -> 37074
# 'Ġconference'        -> 4495
# 'Ġin'                -> 287
# 'Ġneuroscience'      -> 39738
# '.'                  -> 13

# %%
# Let's also try a word with numbers and special characters
text2 = "In 2024, pre-processing costs $123.45!"
tokens2 = tokenizer.tokenize(text2)
print("\nExample 2 tokens:", tokens2)
# Out:
# Example 2 tokens: ['In', 'Ġ2024', ',', 'Ġpre', '-', 'processing', 'Ġcosts', 'Ġ$', '123', '.', '45', '!']

# %% [markdown]
# ### SentencePiece (T5)

# %%
# Load T5 tokenizer which uses SentencePiece
tokenizer = AutoTokenizer.from_pretrained('t5-base')

# Same sentence as before
text = "The ultramarathoner prequalified for the immunohistochemistry conference in neuroscience."

# Tokenize the text
tokens = tokenizer.tokenize(text)
print("Tokens:", tokens)

# Get the token IDs
token_ids = tokenizer.encode(text)
print("\nToken IDs:", token_ids)

# Decode back to show special tokens
decoded = tokenizer.decode(token_ids)
print("\nDecoded with special tokens:", decoded)

# Show the mapping between tokens and their IDs
print("\nToken to ID mapping:")
for token in tokens:
    id = tokenizer.convert_tokens_to_ids(token)
    print(f"{repr(token):20} -> {id}")
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Tokens: ['▁The', '▁ultra', 'mar', 'athon', 'er', '▁pre', 'qualified', '▁for', '▁the', '▁immuno', 'his', 'to', 'chemistry', '▁conference', '▁in', '▁neuroscience', '.']
#
# Token IDs: [37, 6173, 1635, 24718, 49, 554, 23058, 21, 8, 17133, 10193, 235, 11366, 2542, 16, 31542, 5, 1]
#
# Decoded with special tokens: The ultramarathoner prequalified for the immunohistochemistry conference in neuroscience.</s>
#
# Token to ID mapping:
# '▁The'               -> 37
# '▁ultra'             -> 6173
# 'mar'                -> 1635
# 'athon'              -> 24718
# 'er'                 -> 49
# '▁pre'               -> 554
# 'qualified'          -> 23058
# '▁for'               -> 21
# '▁the'               -> 8
# '▁immuno'            -> 17133
# 'his'                -> 10193
# 'to'                 -> 235
# 'chemistry'          -> 11366
# '▁conference'        -> 2542
# '▁in'                -> 16
# '▁neuroscience'      -> 31542
# '.'                  -> 5

# %%
# Let's also try a multilingual example with mixed scripts
text2 = "Tokyo 東京 is beautiful! Pre-processing in 2024 costs $123.45"
tokens2 = tokenizer.tokenize(text2)
print("\nMultilingual example tokens:", tokens2)
# Out:
# Multilingual example tokens: ['▁Tokyo', '▁', '東京', '▁is', '▁beautiful', '!', '▁Pre', '-', 'process', 'ing', '▁in', '▁20', '24', '▁costs', '▁$12', '3.', '45']

# %%
# Let's also look at how it handles whitespace and punctuation
text3 = "  Hello,  world!  "  # Extra spaces
tokens3 = tokenizer.tokenize(text3)
print("\nWhitespace handling example:", tokens3)
# Out:
# Whitespace handling example: ['▁Hello', ',', '▁world', '!']
